# %% [markdown]
# # Introduction
# In this script, I'll try to plot all the different parameters of interest for the battery problem. These parameters are:
# * Battery Pack (ID = 'munisense.msup1g30034')
#     * Power.BatteryState
#     * Power.BatteryVoltHR
#     * Power.PercentageRemaining
#     * Power.TimeRemaining
# * Weather station (ID = 'davis.davis.weather.1')
#     * environment.light
#     * environment.temperature
#     * weather.uv
#     * environment.relativehumidity

# %%
import pandas as pd
import glob

# %% [markdown]
# # Import data from .csv-files

# %% [markdown]
# ## Weather data

# %%
path = r'C:\Users\JeffG\Desktop\Case 1 - data\weather_data'

# %%
##### metricsList is used for the strings (names of the tables) #####
weatherMetricsList = ['environment.light','environment.temperature','weather.uv','environment.relativehumidity']

# %%
##### tableList is used as a list of the newly generated tables #####
weatherList = ['environment.light','environment.temperature','weather.uv','environment.relativehumidity']
##### This loop merges all the csv-files in new dataframes
for i in range(0,len(weatherMetricsList)): 
    dataList = glob.glob(path+'\\'+weatherMetricsList[i]+'_merged'+'*')
    df =  pd.read_csv(dataList[0],  index_col=[0])
    # Select timestamp and value from results
    weatherList[i] = df[['time','value']]
    # Convert object to float (BatteryVoltHR is an object for example)
    weatherList[i]["value"] = pd.to_numeric(weatherList[i].value, errors='coerce')
    # Rename the column
    weatherList[i].rename(columns={'value':weatherMetricsList[i]}, inplace=True)
    # Set timestamp as index
    weatherList[i] = weatherList[i].set_index(pd.DatetimeIndex(pd.to_datetime(weatherList[i].time, unit='ms')))
    weatherList[i].drop(['time'], axis=1,inplace=True)
# Out:
# C:\Users\JeffG\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:472: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %% [markdown]
# ## Battery data

# %%
path = r'C:\Users\JeffG\Desktop\Case 1 - data\battery_data_1'

# %%
##### metricsList is used for the strings (names of the tables) #####
batteryMetricsList = ['Power.BatteryState','Power.BatteryVoltHR','Power.PercentageRemaining','Power.TimeRemaining']

# %%
##### tableList is used as a list of the newly generated tables #####
batteryList_1 = ['Power.BatteryState','Power.BatteryVoltHR','Power.PercentageRemaining','Power.TimeRemaining']
##### This loop merges all the csv-files in new dataframes
for i in range(0,len(batteryMetricsList)): 
    dataList = glob.glob(path+'\\'+batteryMetricsList[i]+'_merged'+'*')
    df =  pd.read_csv(dataList[0],  index_col=[0])
    # Select timestamp and value from results
    batteryList_1[i] = df[['time','value']]
    # Convert object to float (BatteryVoltHR is an object for example)
    batteryList_1[i]["value"] = pd.to_numeric(batteryList_1[i].value, errors='coerce')
    # Rename the column
    batteryList_1[i].rename(columns={'value':batteryMetricsList[i]}, inplace=True)
    # Set timestamp as index
    batteryList_1[i] = batteryList_1[i].set_index(pd.DatetimeIndex(pd.to_datetime(batteryList_1[i].time, unit='ms')))
    batteryList_1[i].drop(['time'], axis=1,inplace=True)
#     print(batteryList[i])

# %%
path = r'C:\Users\JeffG\Desktop\Case 1 - data\battery_data_2'

# %%
##### tableList is used as a list of the newly generated tables #####
batteryList_2 = ['Power.BatteryState','Power.BatteryVoltHR','Power.PercentageRemaining','Power.TimeRemaining']
##### This loop merges all the csv-files in new dataframes
for i in range(0,len(batteryMetricsList)): 
    dataList = glob.glob(path+'\\'+batteryMetricsList[i]+'_merged'+'*')
    df =  pd.read_csv(dataList[0],  index_col=[0])
    # Select timestamp and value from results
    batteryList_2[i] = df[['time','value']]
    # Convert object to float (BatteryVoltHR is an object for example)
    batteryList_2[i]["value"] = pd.to_numeric(batteryList_2[i].value, errors='coerce')
    # Rename the column
    batteryList_2[i].rename(columns={'value':batteryMetricsList[i]}, inplace=True)
    # Set timestamp as index
    batteryList_2[i] = batteryList_2[i].set_index(pd.DatetimeIndex(pd.to_datetime(batteryList_2[i].time, unit='ms')))
    batteryList_2[i].drop(['time'], axis=1,inplace=True)
#     print(batteryList[i])

# %%
path = r'C:\Users\JeffG\Desktop\Case 1 - data\battery_data_3'

# %%
##### tableList is used as a list of the newly generated tables #####
batteryList_3 = ['Power.BatteryState','Power.BatteryVoltHR','Power.PercentageRemaining','Power.TimeRemaining']
##### This loop merges all the csv-files in new dataframes
for i in range(0,len(batteryMetricsList)): 
    dataList = glob.glob(path+'\\'+batteryMetricsList[i]+'_merged'+'*')
    df =  pd.read_csv(dataList[0],  index_col=[0])
    # Select timestamp and value from results
    batteryList_3[i] = df[['time','value']]
    # Convert object to float (BatteryVoltHR is an object for example)
    batteryList_3[i]["value"] = pd.to_numeric(batteryList_3[i].value, errors='coerce')
    # Rename the column
    batteryList_3[i].rename(columns={'value':batteryMetricsList[i]}, inplace=True)
    # Set timestamp as index
    batteryList_3[i] = batteryList_3[i].set_index(pd.DatetimeIndex(pd.to_datetime(batteryList_3[i].time, unit='ms')))
    batteryList_3[i].drop(['time'], axis=1,inplace=True)
#     print(batteryList[i])

# %% [markdown]
# # Visualization

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.io as pio
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
plotly.tools.set_credentials_file(username='jeffgeudens', api_key='fjXUBp4LmaLp1HlNHc6R')
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ## Weather station

# %%
##### TOO MUCH DATA TO PLOT WITH PLOTLY #####
# metricNumber = 0
# data = [go.Scattergl(
#     x=weatherList[metricNumber].index,
#     y=weatherList[metricNumber][weatherMetricsList[metricNumber]])]

# layout = dict(
#     title = weatherMetricsList[metricNumber]
# )

# fig = dict(data=data, layout=layout)
# py.iplot(fig,filename = weatherMetricsList[metricNumber])

# %%
metricNumber = 0
x=weatherList[metricNumber].index
y=weatherList[metricNumber][weatherMetricsList[metricNumber]]

plt.figure(figsize=(15,10))
plt.title(weatherMetricsList[metricNumber])
plt.plot(x,y)
plt.show()
# Out:
# C:\Users\JeffG\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning:
#
# Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()

# %%
metricNumber = 1
x=weatherList[metricNumber].index
y=weatherList[metricNumber][weatherMetricsList[metricNumber]]

plt.figure(figsize=(15,10))
plt.title(weatherMetricsList[metricNumber])
plt.plot(x,y)
plt.show()

# %%
metricNumber = 2
x=weatherList[metricNumber].index
y=weatherList[metricNumber][weatherMetricsList[metricNumber]]

plt.figure(figsize=(15,10))
plt.title(weatherMetricsList[metricNumber])
plt.plot(x,y)
plt.show()

# %%
metricNumber = 3
x=weatherList[metricNumber].index
y=weatherList[metricNumber][weatherMetricsList[metricNumber]]

plt.figure(figsize=(15,10))
plt.title(weatherMetricsList[metricNumber])
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Battery pack

# %%
metricNumber = 1
data = [go.Scattergl(
    x=batteryList_1[metricNumber].index,
    y=batteryList_1[metricNumber][batteryMetricsList[metricNumber]])]

layout = dict(
    title = batteryMetricsList[metricNumber]
)

fig = dict(data=data, layout=layout)
py.iplot(fig,filename = batteryMetricsList[metricNumber])
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jeffgeudens/16.embed" height="525px" width="100%"></iframe>

# %%
metricNumber = 2
data = [go.Scattergl(
    x=batteryList_2[metricNumber].index,
    y=batteryList_2[metricNumber][batteryMetricsList[metricNumber]])]

layout = dict(
    title = batteryMetricsList[metricNumber]
)

fig = dict(data=data, layout=layout)
py.iplot(fig,filename = batteryMetricsList[metricNumber])
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jeffgeudens/18.embed" height="525px" width="100%"></iframe>

# %%
metricNumber = 3
data = [go.Scattergl(
    x=batteryList_3[metricNumber].index,
    y=batteryList_3[metricNumber][batteryMetricsList[metricNumber]])]

layout = dict(
    title = batteryMetricsList[metricNumber]
)

fig = dict(data=data, layout=layout)
py.iplot(fig,filename = batteryMetricsList[metricNumber])
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jeffgeudens/20.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Combination

# %%
fig, ax1 = plt.subplots()
plt.figure(figsize=(15,10))

x1=weatherList[0].index
y1=weatherList[0][weatherMetricsList[0]]
ax1.plot(x1, y1, 'b-')
ax1.set_xlabel('time (s)')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel(weatherMetricsList[0], color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
x2=batteryList_1[1].index
y2=batteryList_1[1][batteryMetricsList[1]]
ax2.plot(x2, y2, 'r-')
ax2.set_ylabel(batteryMetricsList[1], color='r')
ax2.tick_params('y', colors='r')
ax2.set_ylim([0,17])

fig.set_size_inches(18.5, 10.5)

fig.tight_layout()
fig.savefig(r'C:\Users\JeffG\Dropbox\ICT-Elektronica\Thesis\Case 1 - failing battery pack\Images\msup1g30034_voltage_light.png')
plt.show()

# %%
fig, ax1 = plt.subplots()
plt.figure(figsize=(15,10))

x1=weatherList[0].index
y1=weatherList[0][weatherMetricsList[0]]
ax1.plot(x1, y1, 'b-')
ax1.set_xlabel('time (s)')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel(weatherMetricsList[0], color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
x2=batteryList_2[1].index
y2=batteryList_2[1][batteryMetricsList[1]]
ax2.plot(x2, y2, 'r-')
ax2.set_ylabel(batteryMetricsList[1], color='r')
ax2.tick_params('y', colors='r')
ax2.set_ylim([0,17])

fig.set_size_inches(18.5, 10.5)

fig.tight_layout()
fig.savefig(r'C:\Users\JeffG\Dropbox\ICT-Elektronica\Thesis\Case 1 - failing battery pack\Images\msup1i70124_voltage_light.png')

plt.show()

# %%
fig, ax1 = plt.subplots()
plt.figure(figsize=(15,10))

x1=weatherList[0].index
y1=weatherList[0][weatherMetricsList[0]]
ax1.plot(x1, y1, 'b-')
ax1.set_xlabel('time (s)')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel(weatherMetricsList[0], color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
x2=batteryList_3[1].index
y2=batteryList_3[1][batteryMetricsList[1]]
ax2.plot(x2, y2, 'r-')
ax2.set_ylabel(batteryMetricsList[1], color='r')
ax2.tick_params('y', colors='r')
ax2.set_ylim([0,17])

fig.set_size_inches(18.5, 10.5)

fig.tight_layout()
fig.savefig(r'C:\Users\JeffG\Dropbox\ICT-Elektronica\Thesis\Case 1 - failing battery pack\Images\msup1h90115_voltage_light.png')
plt.show()
